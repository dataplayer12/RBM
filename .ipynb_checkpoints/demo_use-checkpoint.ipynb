# %%
import numpy as np
from tensorflow.examples.tutorials.mnist import input_data
from restricted import *
import matplotlib.pyplot as plt

# %% [markdown]
# #### Import MNIST data

# %%
mnist = input_data.read_data_sets('MNIST_data', validation_size=0)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# #### Define RBM

# %%
inputs=mnist.train.images[:10000]
rbm=RBM(inputs,alpha=1e-2,H=100,batchsize=1000,sigma=0.02)

# %%
#rbm.load('mnist_rbm.p') #when loading a pretrained model
# Out:
# Trained RBM loaded

# %% [markdown]
# ## Train

# %%
rbm.fit(epochs=100)

# %% [markdown]
# ## Test reconstruction

# %%
test_image=mnist.test.images[np.random.randint(low=0,high=1000)]
recon=rbm.samplex(rbm.sampleh(test_image[None,:],1),1)
plt.imshow(np.concatenate((test_image.reshape(28,28),recon.reshape(28,28)),axis=1),cmap='gray')
plt.show()

# %%
plt.imshow(rbm.sampleh(test_image[None,:]),cmap='gray') #visualize a hidden vector sampled from distribution
plt.show()

# %% [markdown]
# ### Histogram of weights

# %%
bins,edges=np.histogram(rbm.weights,bins=100)
plt.plot(edges[:-1],bins)
plt.show()

# %% [markdown]
# ### Generate new images. Start with a 3 and generate a 0!

# %%
test_image=mnist.test.images[np.random.randint(low=0,high=1000)][None,:]
recon=rbm.get_xtilda(test_image,k=100) #start with a test image and do 100 steps of Gibbs chain
recon=rbm.samplex(rbm.sampleh(recon,1),1) #samples probabilities so the resulting images are nice to look
plt.imshow(np.concatenate((test_image.reshape(28,28),recon.reshape(28,28)),axis=1),cmap='gray')
plt.show()

# %% [markdown]
# ### Start with random noise and generate a 0

# %%
test_image=np.random.random(size=(1,784))>0.97 #random binary vector
recon=rbm.get_xtilda(test_image,k=100) #start with a test image and do 100 steps of Gibbs chain
recon=rbm.samplex(rbm.sampleh(recon,1),1) #samples probabilities so the resulting images are nice to look
plt.imshow(np.concatenate((test_image.reshape(28,28),recon.reshape(28,28)),axis=1),cmap='gray')
plt.show()
